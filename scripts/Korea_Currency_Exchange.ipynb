# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data = pd.read_csv('../data/Korea_CER.csv')

# %%
# Data Cleaning
# Change the column name to something that is more relevant
# Eliminate rows with no currency data
data.columns = ['date', 'currency']
data = data[data.currency != '.']

# %% [markdown]
# print(data)

# %%
data['currency']
data.to_csv("../data/kor_currency_cleaned.csv")

# %%
ts = pd.Series(data.currency)
ts=ts.astype(float)
# ts = ts[ts > 0.0]

y_pos = np.arange(len(data.date))
plt.xticks(y_pos, data.currency)
plt.ylabel('Currency (Won)')
plt.title('South Korea Currency 8/1/2016 - 10/27/2017')




ts.plot()
plt.show()
